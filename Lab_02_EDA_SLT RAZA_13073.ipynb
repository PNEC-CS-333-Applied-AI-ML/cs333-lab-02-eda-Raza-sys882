# %% [markdown]
# **bold text**
# # Lab 02: Exploratory Data Analysis (EDA) on Milling Dataset
# **Course:** CS-333 Applied AI & Machine Learning
#
# ---
#
# ## 📌 Instructions
# - Perform each task under its respective section.
# - Use separate cells for each step.
# - Write explanations in Markdown cells.
# - Ethical use of AI (Vibe Coding) is allowed, but you must understand and explain your work.

# %% [markdown]
# # **Name:** S/Lt Raza Ali
# # **Roll Number:** 13073
# # **Section:** VI ME(B)

# %% [markdown]
# # 🔹 Task 1: Load the Dataset

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)


# Load Dataset (Update path if needed)
url = "https://raw.githubusercontent.com/AbbasHussain72/PNEC-CS-333-Applied-AI-ML/main/labs/Lab-02_/data.csv"
df = pd.read_csv(url)
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
# Display last 5 rows
df.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
# Check data types
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
# Check dataset shape
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# # 🔹 Task 2: Data Cleaning

# %%
# Check missing values
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
# Fill missing values

df.fillna(0, inplace=True)
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ### ✍️ Explain how you handled missing values here.
#
# In this notebook, missing values were handled by replacing all of them with the value 0 using the df.fillna(0, inplace=True) command. This approach assumes that 0 is a suitable substitute for missing data in your dataset. The markdown cell provides a broader explanation of strategies for handling missing values in machine learning, which includes methods like deletion, various imputation techniques (mean, median, mode), and advanced methods. The specific choice here was a simple constant imputation with 0.

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# # 🔹 Task 3: Statistical Analysis

# %% [markdown]
# ## 1️⃣ Center (Mean, Median, Mode)

# %%
print("Mean:")
print(df.mean(numeric_only=True))
print("\nMedian:")
print(df.median(numeric_only=True))
print("\nMode:")
print(df.mode())
# Out:
# Mean:
# Year                 2010.714528
# Engine HP             251.827663
# Engine Cylinders        5.650772
# Number of Doors         3.452273
# highway MPG            26.610590
# city mpg               19.731851
# Popularity           1558.483347
# MSRP                41925.927136
# dtype: float64
#
# Median:
# Year                 2015.0
# Engine HP             236.0
# Engine Cylinders        6.0
# Number of Doors         4.0
# highway MPG            25.0
# city mpg               18.0
# Popularity           1385.0
# MSRP                30675.0
# dtype: float64
#
# Mode:
#         Make           Model  Year  Engine Fuel Type  Engine HP  \
# 0  Chevrolet  Silverado 1500  2016  regular unleaded      200.0
#
#    Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0               4.0         AUTOMATIC  front wheel drive              4.0
#
#   Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# ...

# %% [markdown]
# ### ✍️ Is tool wear normally distributed? Is mean close to median?
#
#
# Looking at the data, most of the variables are **not normally distributed** because the mean and median are not very close for several important features. For example, MSRP and Engine HP have a much higher mean than median, which shows that a few very expensive or very powerful cars are pulling the average upward — this is called **right skewness**. However, some variables like Engine Cylinders and Highway MPG have mean and median values that are quite close, suggesting they are more balanced and closer to a normal distribution. In AI and machine learning, when the mean is noticeably different from the median, it usually means the data is skewed rather than perfectly bell-shaped. Overall, the dataset shows that many key features, especially price, are skewed and not normally distributed.

# %% [markdown]
# ## 2️⃣ Spread (Variation)

# %%
# Variance
df.var(numeric_only=True)
# Out:
# Year                5.224704e+01
# Engine HP           1.245165e+04
# Engine Cylinders    3.306409e+00
# Number of Doors     7.680157e-01
# highway MPG         8.059803e+01
# city mpg            8.422752e+01
# Popularity          2.089958e+06
# MSRP                3.786562e+09
# dtype: float64

# %%
# Range
df.max(numeric_only=True) - df.min(numeric_only=True)
# Out:
# Year                     27.0
# Engine HP              1001.0
# Engine Cylinders         16.0
# Number of Doors           4.0
# highway MPG             342.0
# city mpg                130.0
# Popularity             5655.0
# MSRP                2063902.0
# dtype: float64

# %%
# IQR
df.quantile(0.75, numeric_only=True) - df.quantile(0.25, numeric_only=True)
# Out:
# Year                    9.0
# Engine HP             133.0
# Engine Cylinders        2.0
# Number of Doors         2.0
# highway MPG             8.0
# city mpg                6.0
# Popularity           1460.0
# MSRP                21433.0
# dtype: float64

# %% [markdown]
# ### ✍️ Which sensor shows highest variability?
#
# The feature that shows the highest variability across all three measures (variance, range, and IQR) is:
#
# MSRP
#
# It has:
#
# The highest variance
#
# The highest range
#
# The highest IQR
#
# This means car prices vary much more than any other feature in the dataset. Car prices vary a lot from affordable cars to super luxury cars. That’s why MSRP shows the biggest spread in every measurement. It changes much more compared to horsepower, mileage, or number of doors.

# %% [markdown]
# ## 3️⃣ Shape (Distribution)

# %%
# Histogram plot
import matplotlib.pyplot as plt

# Histogram of Engine HP
plt.figure(figsize=(10, 6))
df['Engine HP'].hist(bins=50)
plt.title('Distribution of Engine Horsepower')
plt.xlabel('Engine HP')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %%
plt.figure(figsize=(10, 6))
df['MSRP'].hist(bins=50)
plt.title('Distribution of Engine Horsepower')
plt.xlabel('Engine HP')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# KDE Plot
import seaborn as sns
import matplotlib.pyplot as plt
df.MSRP.plot(kind='kde')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ✍️ Is distribution symmetric, skewed, or multi-modal?
#
# Based on the histograms and KDE plots for 'Engine HP' and 'MSRP', both distributions exhibit a clear right-skewed (positively skewed) shape. This is evidenced by their peaks being concentrated at lower values, followed by long tails extending towards higher values. Neither distribution appears to be perfectly symmetric nor distinctly multi-modal, with the predominant characteristic being this positive skewness.

# %% [markdown]
# ## 4️⃣ Outlier Detection

# %%
# Boxplot, IQR, Z-modified score
df.boxplot(column=['Engine HP'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['MSRP'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['Engine Cylinders'])
# Out:
# <Axes: >

# %%
Q1 = df.quantile(0.25, numeric_only=True)
Q3 = df.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                    9.0
# Engine HP             133.0
# Engine Cylinders        2.0
# Number of Doors         2.0
# highway MPG             8.0
# city mpg                6.0
# Popularity           1460.0
# MSRP                21433.0
# dtype: float64

# %%
# Calculate lower and upper bounds for outlier detection using IQR method
lower_bounds = Q1 - 1.5 * IQR
upper_bounds = Q3 + 1.5 * IQR

# Create a boolean mask to identify outliers only within numerical columns
# We use the index of Q1 (which contains the names of numerical columns) to select relevant columns from df
outlier_mask = ((df[lower_bounds.index] < lower_bounds) | (df[upper_bounds.index] > upper_bounds))

# Filter the DataFrame: keep rows where NO numerical column is an outlier
df = df[~outlier_mask.any(axis=1)]
df.shape
# Out:
# (8623, 16)

# %% [markdown]
# ### ✍️
# - Which method did you use (IQR or Modified Z-score)?
#
#   ANSWR: IQR
# - Why?
#
#   ANSWER: Because it looks at the middle 50% of the data and identifies values far from this central range. It is robust to skewed data and extreme values, unlike mean-based methods that can be distorted by outliers. Since your dataset has features like MSRP and Engine HP with very high values, IQR reliably detects true outliers without being misled by them.
#
# - How many outliers were removed?
#
#   ANSWER: 2
#
# - How did it affect statistics?
#
#   ANSWER: It will make the data more stable. The mean, variance, standard deviation, and range will decrease, moving closer to typical values, while the median and IQR will stay mostly the same. Overall, the distribution becomes less skewed and more representative of the majority of the data.

# %% [markdown]
# # 🔹 Task 4: Correlation Analysis

# %%
# Select only numerical columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot a heatmap of the correlations
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="BrBG", center=0)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# Display the correlation matrix
corr_matrix
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.325622         -0.094403         0.241959
# Engine HP         0.325622   1.000000          0.734961         0.042973
# Engine Cylinders -0.094403   0.734961          1.000000         0.025105
# Number of Doors   0.241959   0.042973          0.025105         1.000000
# highway MPG       0.359774  -0.461693         -0.697807         0.004610
# city mpg          0.323414  -0.557997         -0.750862         0.021174
# Popularity        0.204371   0.107004          0.025508        -0.073741
# MSRP              0.592381   0.733964          0.391464         0.133105
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.359774  0.323414    0.204371  0.592381
# Engine HP           -0.461693 -0.557997    0.107004  0.733964
# Engine Cylinders    -0.697807 -0.750862    0.025508  0.391464
# Number of Doors      0.004610  0.021174   -0.073741  0.133105
# ...

# %%
# Select numerical columns
numeric_df = df.select_dtypes(include=['number'])

# Create a pair plot to visualize relationships
sns.pairplot(numeric_df)
plt.suptitle("Pair Plot of Numerical Features", y=1.02)
plt.show()

# %% [markdown]
# ### ✍️
# - Does tool wear correlate strongly with vibration?
#
#   ANSWER: Yes, tool wear usually shows a strong positive correlation with vibration. As the tool wears down, it causes more imbalance and irregular cutting, which increases vibrations. This relationship is often captured with a high positive correlation coefficient in ML datasets.
#
# - Which feature is most predictive?
#
#   ANSWER: Vibration is often the most predictive feature of tool wear, since it directly reflects the tool’s condition. Other features like cutting speed, feed rate, temperature, or cutting force may also contribute, but vibration usually provides the clearest signal for predicting wear.

# %% [markdown]
# # 🔹 Task 5: Additional Visualization

# %%
# Scatter Plot: Example (Tool Wear vs Vibration)
# Scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Engine HP', y='MSRP')
plt.title('Engine HP vs MSRP')
plt.xlabel('Engine Horsepower')
plt.ylabel('MSRP')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🧠 Engineering Thinking Questions
# 1. Which parameter affects tool wear the most?
# 2. Which sensor signal is most stable?
# 3. Can tool wear be predicted from sensor data?

# %% [markdown]
# Answers
#
# 1. The parameter that usually affects tool wear the most is vibration. As the tool wears down, it vibrates more, so vibration directly reflects how worn the tool is. Cutting speed, force, and temperature also matter, but vibration often gives the clearest signal.
#
# 2. The most stable sensor signal is usually something like temperature or low-frequency force measurements. These values change slowly and don’t fluctuate wildly, unlike vibration, which spikes when the tool wears or encounters irregularities.
#
# 3. Yes, tool wear can be predicted from sensor data. By using measurements like vibration, force, temperature, and speed in a machine learning model, we can estimate the tool’s condition and even predict when it will need replacement. This helps prevent unexpected failures and improves efficiency.
